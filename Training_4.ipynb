# %% [markdown]
# # Objective or Ideation or Concept

# %% [markdown]
# Wheat production by countries
# - Descriptive statistics
# - Trends
# - Insights
# - GIS data visualisations

# %% [markdown]
# # ETL (Extract, Transform, Load)

# %% [markdown]
# ## Extract

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/International_wheat_production_statistics'

# %%
df=pd.read_html(url)[0]

# %%
df.head()
# Out:
#          Country  2020[1] 2019[1] 2018[1] 2017[1] 2016[1] 2015[2] 2014[3]  \
# 0          China    134.3   133.6   131.4   134.3   131.7   130.2   126.2
# 1          India    107.6   103.6    99.7    98.5    93.5    86.5    94.5
# 2         Russia     85.9    74.5    72.1    85.9    73.3    61.8    59.7
# 3  United States     49.7    52.3    51.3    47.3    62.9    55.8    55.4
# 4         Canada     35.2    32.3    31.8    30.0    30.5    27.6    29.3
#
#   2013[4] 2012[5]  ... 2005 [6]  2004[6]  2003[6]  2002  2001  2000   1999  \
# 0   121.7   125.6  ...     96.3     91.6     86.5  90.3  93.9  99.7  113.9
# 1    93.5    94.9  ...     72.0     72.1     65.1  72.8  69.7  76.4   70.8
# 2    52.1    37.7  ...     47.6     45.4     34.1  50.6  47.0  34.5   31.0
# 3    60.0    61.8  ...     57.1     58.7     63.8  44.1  53.3  60.8   62.7
# 4    37.5    27.0  ...     25.6     25.9     23.6  16.2  20.6  26.8   26.9
#
#     1998   1997   1996
# 0  109.7  123.3  110.6
# ...

# %% [markdown]
# ## Transform

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   42 non-null     string
#  1   2020[1]   42 non-null     float64
#  2   2019[1]   42 non-null     float64
#  3   2018[1]   42 non-null     object
#  4   2017[1]   42 non-null     object
#  5   2016[1]   42 non-null     object
#  6   2015[2]   42 non-null     object
#  7   2014[3]   42 non-null     object
#  8   2013[4]   42 non-null     object
#  9   2012[5]   42 non-null     object
#  10  2011[5]   42 non-null     object
#  11  2010[5]   42 non-null     float64
#  12  2009[5]   42 non-null     float64
#  13  2008[5]   42 non-null     float64
#  14  2007[5]   42 non-null     float64
#  15  2006[5]   42 non-null     float64
#  16  2005 [6]  42 non-null     float64
#  17  2004[6]   42 non-null     float64
#  18  2003[6]   42 non-null     float64
#  19  2002      42 non-null     float64
# ...

# %%
df['Country']=df['Country'].astype('string')

# %%
df['2019[1]']=df['2019[1]'].str.replace('[7]', '')

# %%
df['2019[1]']= df['2019[1]'].astype('float')

# %%
df['2019[1]'].unique()
# Out:
# array(['133.6', '103.6', '74.5', '52.3', '32.3', '40.6', '24.4', '28.4',
#        '23.1', '19.0', '19.5', '16.8[7]', '17.6', '11.3', '10.8', '16.2',
#        '9.0[7]', '6.0', '10.3', '6.7', '5.6', '4.3', '6.1', '5.3', '4.9',
#        '5.4', '4.8', '6.3', '3.8', '4.6', '3.5', '3.9', '3.2', '2.5',
#        '3.1', '2.3', '2.4', '4.0', '2.0', '1.9', '1.5', '765.8'],
#       dtype=object)

# %%
df['2019[1]'].str.replace('[7]', '')
# Out:
# array(['133.6', '103.6', '74.5', '52.3', '32.3', '40.6', '24.4', '28.4',
#        '23.1', '19.0', '19.5', '16.8', '17.6', '11.3', '10.8', '16.2',
#        '9.0', '6.0', '10.3', '6.7', '5.6', '4.3', '6.1', '5.3', '4.9',
#        '5.4', '4.8', '6.3', '3.8', '4.6', '3.5', '3.9', '3.2', '2.5',
#        '3.1', '2.3', '2.4', '4.0', '2.0', '1.9', '1.5', '765.8'],
#       dtype=object)

# %%
df.describe().T
# Out:
#           count       mean         std  min    25%   50%     75%    max
# 2020[1]    42.0  35.607143  118.051294  2.1  3.425  6.50  20.325  760.9
# 2019[1]    42.0  35.790476  118.590210  1.5  3.925  6.20  19.375  765.8
# 2010[5]    42.0  30.035714   99.115173  1.0  3.100  5.90  19.000  640.3
# 2009[5]    42.0  31.883333  105.770861  1.0  3.175  6.10  20.825  684.2
# 2008[5]    42.0  31.754762  105.344316  1.0  2.275  6.40  20.200  681.0
# 2007[5]    42.0  28.350000   93.957132  0.8  2.300  5.35  16.500  606.7
# 2006[5]    42.0  28.411905   94.956257  0.6  2.725  5.85  14.650  614.5
# 2005 [6]   42.0  29.226190   96.637144  0.7  2.775  5.65  20.425  626.9
# 2004[6]    42.0  29.369048   97.756897  0.5  2.725  6.55  19.000  634.9
# 2003[6]    42.0  25.830952   84.966750  0.5  2.350  5.95  17.875  550.1
# 2002       42.0  27.107143   91.354369  0.5  2.625  4.90  16.150  592.0
# 2001       42.0  27.397619   90.789627  0.5  2.500  5.10  19.000  588.2
# ...

# %%
df.replace(to_replace={'[7]':''})
# Out:
#            Country  2020[1]  2019[1]  2018[1]  2017[1]  2016[1] 2015[2]  \
# 0            China    134.3    133.6    131.4    134.3    131.7   130.2
# 1            India    107.6    103.6     99.7     98.5     93.5    86.5
# 2           Russia     85.9     74.5     72.1     85.9     73.3    61.8
# 3    United States     49.7     52.3     51.3     47.3     62.9    55.8
# 4           Canada     35.2     32.3     31.8     30.0     30.5    27.6
# 5           France     30.1     40.6     35.8     36.9     29.5    42.8
# 6         Pakistan     25.2     24.4     25.1     26.7     26.0    25.1
# 7          Ukraine     24.9     28.4     24.7     26.2     26.1    26.5
# 8          Germany     22.2     23.1     20.3     24.5     24.5    26.5
# 9           Turkey     20.5     19.0     20.0     21.5     20.6    22.6
# 10       Argentina     19.8     19.5     18.5     18.4     18.6    11.6
# 11            Iran     15.0     16.8  14.5[7]  14.0[7]  11.1[7]    11.5
# ...

# %%
cols_df=list(df.select_dtypes(include='object').columns)
for i in cols_df:
    df[i].replace('[7]', '')

# %%
# Select object columns
object_columns = df.select_dtypes(include='object').columns

# Perform replacement for each object column
for col in object_columns:
    df[col] = df[col].str.replace(r'\[7\]', '',regex=True)

# %%
# Select object columns
object_columns = df.select_dtypes(include='object').columns

# Perform replacement for each object column
for col in object_columns:
    df[col] = df[col].str.replace(r'\[8\]', '',regex=True)

# %%
# Select object columns
object_columns = df.select_dtypes(include='object').columns

# Perform replacement for each object column
for col in object_columns:
    df[col] = df[col].str.replace(r'\[\d\]', '',regex=True)

# %%
for i in object_columns:
    df[i] = df[i].astype('float')

# %%
df.columns=df.columns.str.replace(r'\[\d\]', '',regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  42 non-null     string
#  1   2020     42 non-null     float64
#  2   2019     42 non-null     float64
#  3   2018     42 non-null     float64
#  4   2017     42 non-null     float64
#  5   2016     42 non-null     float64
#  6   2015     42 non-null     float64
#  7   2014     42 non-null     float64
#  8   2013     42 non-null     float64
#  9   2012     42 non-null     float64
#  10  2011     42 non-null     float64
#  11  2010     42 non-null     float64
#  12  2009     42 non-null     float64
#  13  2008     42 non-null     float64
#  14  2007     42 non-null     float64
#  15  2006     42 non-null     float64
#  16  2005     42 non-null     float64
#  17  2004     42 non-null     float64
#  18  2003     42 non-null     float64
#  19  2002     42 non-null     float64
# ...

# %% [markdown]
# ## EDA

# %%
df.describe().T[['max']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe().T['mean'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe().T['50%'].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            Country   2020   2019   2018   2017   2016   2015   2014   2013  \
# 0            China  134.3  133.6  131.4  134.3  131.7  130.2  126.2  121.7
# 1            India  107.6  103.6   99.7   98.5   93.5   86.5   94.5   93.5
# 2           Russia   85.9   74.5   72.1   85.9   73.3   61.8   59.7   52.1
# 3    United States   49.7   52.3   51.3   47.3   62.9   55.8   55.4   60.0
# 4           Canada   35.2   32.3   31.8   30.0   30.5   27.6   29.3   37.5
# 5           France   30.1   40.6   35.8   36.9   29.5   42.8   39.0   38.6
# 6         Pakistan   25.2   24.4   25.1   26.7   26.0   25.1   26.0   24.2
# 7          Ukraine   24.9   28.4   24.7   26.2   26.1   26.5   24.1   22.8
# 8          Germany   22.2   23.1   20.3   24.5   24.5   26.5   27.8   25.0
# 9           Turkey   20.5   19.0   20.0   21.5   20.6   22.6   19.0   22.1
# 10       Argentina   19.8   19.5   18.5   18.4   18.6   11.6   13.9    8.0
# ...

# %%
df=df.loc[df['Country'] != 'World total']

# %%
df.describe().T[['max']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe().T['mean'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df=df.set_index('Country')

# %%
df['Average']=df.mean(axis=1)
df['Std']=df.std(axis=1)
df['Max']=df.max(axis=1)
df['Min']=df.min(axis=1)

# %%
df
# Out:
#                  2020   2019   2018   2017   2016   2015   2014   2013   2012  \
# Country
# China           134.3  133.6  131.4  134.3  131.7  130.2  126.2  121.7  125.6
# India           107.6  103.6   99.7   98.5   93.5   86.5   94.5   93.5   94.9
# Russia           85.9   74.5   72.1   85.9   73.3   61.8   59.7   52.1   37.7
# United States    49.7   52.3   51.3   47.3   62.9   55.8   55.4   60.0   61.8
# Canada           35.2   32.3   31.8   30.0   30.5   27.6   29.3   37.5   27.0
# France           30.1   40.6   35.8   36.9   29.5   42.8   39.0   38.6   40.3
# Pakistan         25.2   24.4   25.1   26.7   26.0   25.1   26.0   24.2   23.5
# Ukraine          24.9   28.4   24.7   26.2   26.1   26.5   24.1   22.8   15.8
# Germany          22.2   23.1   20.3   24.5   24.5   26.5   27.8   25.0   22.4
# Turkey           20.5   19.0   20.0   21.5   20.6   22.6   19.0   22.1   20.1
# Argentina        19.8   19.5   18.5   18.4   18.6   11.6   13.9    8.0   11.0
# ...
